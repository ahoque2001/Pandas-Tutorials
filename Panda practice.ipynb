# %%
import pandas as pd

data = {'apple': [3,4,0],'Orange': [5,6,0,1]}

# %%
student = {'name':['Azizul','Shiplu','Turan'],
           'Reg-No':[9090,8080,7070],
           'admit Date':['01-dec-2004','04-dec-2004','05-nov-2004']}

# %%
student
# Out:
# {'name': ['Azizul', 'Shiplu', 'Turan'],
#  'Reg-No': [9090, 8080, 7070],
#  'admit Date': ['01-dec-2004', '04-dec-2004', '05-nov-2004']}

# %%
df = pd.DataFrame(student)

# %% [markdown]
# df.head()

# %%
c_o={'course_name':['Statistics','Physics','AI'],
     'Course_id':['001','002','003'],
     'Course_teacher':['Sentos','John','CK']}
course_outline=pd.DataFrame(c_o)

# %%
course_outline.head()
# Out:
#   course_name Course_id Course_teacher
# 0  Statistics       001         Sentos
# 1     Physics       002           John
# 2          AI       003             CK

# %%
course_outline.to_csv('dataset/course_outline.csv')

# %%
first_col=df.iloc[:,0]

print(first_col)
# Out:
# 0    Azizul
# 1    Shiplu
# 2     Turan
# Name: name, dtype: object

# %%
#Student_take=pd.DataFrame(c_o,index=['Aziz','Rahim','sohel'])
Student_take=pd.DataFrame(c_o,index=df.iloc[:,0])

# %%
Student_take.head()
# Out:
#        course_name Course_id Course_teacher
# name
# Azizul  Statistics       001         Sentos
# Shiplu     Physics       002           John
# Turan           AI       003             CK

# %%
Student_take.loc['Shiplu']
# Out:
# course_name       Physics
# Course_id             002
# Course_teacher       John
# Name: Shiplu, dtype: object

# %%
Student_take.to_csv('dataset/students.csv')

# %%
df=pd.read_csv('dataset/students.csv')

# %%
df.head()
# Out:
#      name course_name  Course_id Course_teacher
# 0  Azizul  Statistics          1         Sentos
# 1  Shiplu     Physics          2           John
# 2   Turan          AI          3             CK

# %%
df1=df.append(pd.DataFrame({'name':['arif'],'course_name':['Physics'],
                            'Course_id':['2'],
                            'Course_teacher':['John']}),ignore_index=True)

# %%
df1.head()
df2=pd.DataFrame({'name':['Dhiman'],
                  'course_name':['AI'],
                  'Course_id':[''],
                  'Course_teacher':['CK']})

# %%
df1=df1.append(df2,ignore_index=True)

# %%
df1.head()
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK

# %%
df.to_json('dataset/student.json')

# %%
df1.shape
# Out:
# (5, 4)

# %%
movie_df=pd.read_csv("dataset/IMDB-Movie-Data.csv")

# %%
movie_df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
movie_df.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %%
movie_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movie_df.shape
# Out:
# (1000, 12)

# %%
temp_df=movie_df.append(movie_df)

# %%
temp_df.shape
# Out:
# (2000, 12)

# %%
#checking duplicate records in data frame
temp_df.duplicated(['Rank','Title'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Length: 2000, dtype: bool

# %%
duplicate_student=df1.append(df1,ignore_index=True)

# %%
duplicate_student
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK
# 5  Azizul  Statistics         1         Sentos
# 6  Shiplu     Physics         2           John
# 7   Turan          AI         3             CK
# 8    arif     Physics         2           John
# 9  Dhiman          AI                       CK

# %%
# Duplicacy checker
check_dp_std=duplicate_student[duplicate_student.duplicated()]

# %%
check_dp_std
# Out:
#      name course_name Course_id Course_teacher
# 5  Azizul  Statistics         1         Sentos
# 6  Shiplu     Physics         2           John
# 7   Turan          AI         3             CK
# 8    arif     Physics         2           John
# 9  Dhiman          AI                       CK

# %%
duplicate_student.drop_duplicates(inplace=True)

# %%
duplicate_student.head()
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK

# %%
duplicate_student.head()
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK

# %%
dup_std=df1.append(df1,ignore_index=True)

# %%
dup_std
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK
# 5  Azizul  Statistics         1         Sentos
# 6  Shiplu     Physics         2           John
# 7   Turan          AI         3             CK
# 8    arif     Physics         2           John
# 9  Dhiman          AI                       CK

# %%
dup_std.drop_duplicates(keep=False,inplace=True)

# %%
dup_std.head()
# Out:
# Empty DataFrame
# Columns: [name, course_name, Course_id, Course_teacher]
# Index: []

# %%
dup_std.head()
# Out:
# Empty DataFrame
# Columns: [name, course_name, Course_id, Course_teacher]
# Index: []

# %%
temp_df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
temp_df.duplicated
# Out:
# <bound method DataFrame.duplicated of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
temp_df[temp_df['Rank']<5].head(10)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# ...

# %%
movie_df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# Column renaming Single column, upper, lower 

movie_df.rename(columns={
    'Revenue (Millions)':'Revenue',
    'Runtime (Minutes)' :'Runtime'
},inplace=True)

# %%
movie_df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
movie_df.columns=['rank', 'title', 'genre', 'Description', 'Director', 'Actors', 'Year',
       'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore']

# %%
movie_df.columns
# Out:
# Index(['rank', 'title', 'genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime', 'Rating', 'Votes', 'Revenue', 'Metascore'],
#       dtype='object')

# %%
movie_df.columns=[col.lower() for col in movie_df]

# %%
movie_df.columns
# Out:
# Index(['rank', 'title', 'genre', 'description', 'director', 'actors', 'year',
#        'runtime', 'rating', 'votes', 'revenue', 'metascore'],
#       dtype='object')

# %%
movie_df.columns=[col.upper() for col in movie_df]

# %%
movie_df.columns
# Out:
# Index(['RANK', 'TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME', 'RATING', 'VOTES', 'REVENUE', 'METASCORE'],
#       dtype='object')

# %% [markdown]
# # Null value detection in Pandas Data frame

# %% [markdown]
# ##Two way to deal with NULL values 1. Get rid of rows and column with NULLs and 2. Replace NUll with NON Null values called IMPUTATION

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RANK         1000 non-null   int64
#  1   TITLE        1000 non-null   object
#  2   GENRE        1000 non-null   object
#  3   DESCRIPTION  1000 non-null   object
#  4   DIRECTOR     1000 non-null   object
#  5   ACTORS       1000 non-null   object
#  6   YEAR         1000 non-null   int64
#  7   RUNTIME      1000 non-null   int64
#  8   RATING       1000 non-null   float64
#  9   VOTES        1000 non-null   int64
#  10  REVENUE      872 non-null    float64
#  11  METASCORE    936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
movie_df.isnull()
# Out:
#       RANK  TITLE  GENRE  DESCRIPTION  DIRECTOR  ACTORS   YEAR  RUNTIME  \
# 0    False  False  False        False     False   False  False    False
# 1    False  False  False        False     False   False  False    False
# 2    False  False  False        False     False   False  False    False
# 3    False  False  False        False     False   False  False    False
# 4    False  False  False        False     False   False  False    False
# ..     ...    ...    ...          ...       ...     ...    ...      ...
# 995  False  False  False        False     False   False  False    False
# 996  False  False  False        False     False   False  False    False
# 997  False  False  False        False     False   False  False    False
# 998  False  False  False        False     False   False  False    False
# 999  False  False  False        False     False   False  False    False
#
#      RATING  VOTES  REVENUE  METASCORE
# 0     False  False    False      False
# ...

# %%
movie_df.isnull().sum()
# Out:
# RANK             0
# TITLE            0
# GENRE            0
# DESCRIPTION      0
# DIRECTOR         0
# ACTORS           0
# YEAR             0
# RUNTIME          0
# RATING           0
# VOTES            0
# REVENUE        128
# METASCORE       64
# dtype: int64

# %%
df_m=movie_df[['RANK','REVENUE']]
df_m
# Out:
#      RANK  REVENUE
# 0       1   333.13
# 1       2   126.46
# 2       3   138.12
# 3       4   270.32
# 4       5   325.02
# ..    ...      ...
# 995   996      NaN
# 996   997    17.54
# 997   998    58.01
# 998   999      NaN
# 999  1000    19.64
#
# [1000 rows x 2 columns]

# %%
df_m[df_m['REVENUE'].isnull()]
# Out:
#      RANK  REVENUE
# 7       8      NaN
# 22     23      NaN
# 25     26      NaN
# 39     40      NaN
# 42     43      NaN
# ..    ...      ...
# 977   978      NaN
# 978   979      NaN
# 988   989      NaN
# 995   996      NaN
# 998   999      NaN
#
# [128 rows x 2 columns]

# %%
movie_df['REVENUE'].dtype
# Out:
# dtype('float64')

# %%
movie_df.isnull().sum()
# Out:
# RANK             0
# TITLE            0
# GENRE            0
# DESCRIPTION      0
# DIRECTOR         0
# ACTORS           0
# YEAR             0
# RUNTIME          0
# RATING           0
# VOTES            0
# REVENUE        128
# METASCORE       64
# dtype: int64

# %%
df_m.isnull().sum()
# Out:
# RANK         0
# REVENUE    128
# dtype: int64

# %%
df_m.dropna(inplace=True)
# Out:
# <ipython-input-337-e83389b64a85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_m.dropna(inplace=True)

# %%
df_m.isnull().sum()
# Out:
# RANK       0
# REVENUE    0
# dtype: int64

# %%
df_m.isnull().sum()
# Out:
# RANK       0
# REVENUE    0
# dtype: int64

# %%
df_m.shape
# Out:
# (872, 2)

# %%
movie_df.isnull().sum()
# Out:
# RANK             0
# TITLE            0
# GENRE            0
# DESCRIPTION      0
# DIRECTOR         0
# ACTORS           0
# YEAR             0
# RUNTIME          0
# RATING           0
# VOTES            0
# REVENUE        128
# METASCORE       64
# dtype: int64

# %% [markdown]
# # Imputation : it is nothing but replacing data to the NULL place with MEAN or MEDIAN of that column

# %%
revenue=movie_df['REVENUE']

# %%
revenue.head()
# Out:
# 0    333.13
# 1    126.46
# 2    138.12
# 3    270.32
# 4    325.02
# Name: REVENUE, dtype: float64

# %%
movie_df.columns
# Out:
# Index(['RANK', 'TITLE', 'GENRE', 'DESCRIPTION', 'DIRECTOR', 'ACTORS', 'YEAR',
#        'RUNTIME', 'RATING', 'VOTES', 'REVENUE', 'METASCORE'],
#       dtype='object')

# %%
revenue_mean=revenue.mean()

# %%
revenue_mean
# Out:
# 82.95637614678897

# %% [markdown]
# ##With this mean value now we can fill it up NULL using fillna()

# %%
revenue.fillna(revenue_mean,inplace=True)

# %%
revenue.isnull().sum()
# Out:
# 0

# %%
movie_df.isnull().sum()
# Out:
# RANK            0
# TITLE           0
# GENRE           0
# DESCRIPTION     0
# DIRECTOR        0
# ACTORS          0
# YEAR            0
# RUNTIME         0
# RATING          0
# VOTES           0
# REVENUE         0
# METASCORE      64
# dtype: int64

# %%
metaschore=movie_df['METASCORE']

# %%
metaschore.isnull().sum()
# Out:
# 64

# %%
mean_meta=metaschore.mean()

# %%
mean_meta
# Out:
# 58.98504273504273

# %%
metaschore.fillna(mean_meta,inplace=True)

# %%
metaschore.isnull().sum()
# Out:
# 0

# %%
movie_df.isnull().sum()
# Out:
# RANK           0
# TITLE          0
# GENRE          0
# DESCRIPTION    0
# DIRECTOR       0
# ACTORS         0
# YEAR           0
# RUNTIME        0
# RATING         0
# VOTES          0
# REVENUE        0
# METASCORE      0
# dtype: int64

# %%
movie_df.tail()
# Out:
#      RANK                   TITLE                  GENRE  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            DESCRIPTION          DIRECTOR  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 ACTORS  YEAR  RUNTIME  RATING  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015      111     6.2
# ...

# %%
m_u=movie_df.nunique()

# %%
print(m_u)
# Out:
# RANK           1000
# TITLE           999
# GENRE           207
# DESCRIPTION    1000
# DIRECTOR        644
# ACTORS          996
# YEAR             11
# RUNTIME          94
# RATING           55
# VOTES           997
# REVENUE         815
# METASCORE        85
# dtype: int64

# %%
movie_df['GENRE'].groupby
# Out:
# <bound method Series.groupby of 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: GENRE, Length: 1000, dtype: object>

# %%
md=movie_df[['GENRE','REVENUE']]

# %%
md.isnull().sum()
# Out:
# GENRE      0
# REVENUE    0
# dtype: int64

# %%
md.count()
# Out:
# GENRE      1000
# REVENUE    1000
# dtype: int64

# %%
Gen_H=md[md['GENRE']=='Action,Adventure,Sci-Fi']

# %%
Gen_H.shape
# Out:
# (50, 2)

# %%
Gen_H.insert(2,"M_Re_Horr","NaN")

# %%
Gen_H.shape
# Out:
# (50, 3)

# %%
mean_r_HOR = Gen_H["REVENUE"].mean()

# %%
mean_r_HOR
# Out:
# 209.23020000000005

# %%
Gen_H.fillna()

# %%
mov_df=pd.read_csv("dataset/IMDB-Movie-Data.csv")

# %%
mov_df.shape
# Out:
# (1000, 12)

# %%
mov_df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
mov_df.rename(columns={'Revenue (Millions)':'Revenue'},inplace=True)

# %%
mov_df.isnull().sum()
# Out:
# Rank                   0
# Title                  0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue              128
# Metascore             64
# dtype: int64

# %%
mov_df['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
rev_gen_df=mov_df[['Genre','Revenue']]

# %%
rev_gen_df.shape
# Out:
# (1000, 2)

# %%
rev_gen_df_n=rev_gen_df[rev_gen_df['Revenue'].isnull()]

# %%
rev_gen_df_n['Genre'].groupby
# Out:
# <bound method Series.groupby of 7                   Comedy
# 22      Crime,Drama,Horror
# 25                  Comedy
# 39            Comedy,Drama
# 42                  Horror
#               ...
# 977                 Comedy
# 978                  Drama
# 988                 Horror
# 995    Crime,Drama,Mystery
# 998       Adventure,Comedy
# Name: Genre, Length: 128, dtype: object>

# %%
rev_gen_df.shape
# Out:
# (1000, 2)

# %%
rev_gen_df.isnull().sum()
# Out:
# Genre        0
# Revenue    128
# dtype: int64

# %%
rev_t=rev_gen_df.groupby('Genre')['Revenue'].mean()

# %%
rev_t.tail(n=50)
# Out:
# Genre
# Drama,Fantasy,Mystery        42.270000
# Drama,Fantasy,Romance        95.217500
# Drama,Fantasy,Thriller       43.980000
# Drama,Fantasy,War            37.620000
# Drama,History                40.220000
# Drama,History,Thriller       53.897500
# Drama,History,War             0.860000
# Drama,Horror                  9.275000
# Drama,Horror,Musical         52.880000
# Drama,Horror,Mystery         38.523333
# Drama,Horror,Sci-Fi          58.686000
# Drama,Horror,Thriller        16.110000
# Drama,Music                  20.306667
# Drama,Music,Romance          30.800000
# Drama,Musical,Romance       148.780000
# Drama,Mystery,Romance        27.988333
# Drama,Mystery,Sci-Fi         37.548000
# Drama,Mystery,Thriller       19.585000
# Drama,Mystery,War             6.860000
# Drama,Romance                30.683667
# Drama,Romance,Sci-Fi         17.752500
# Drama,Romance,Thriller      118.750000
# Drama,Romance,War                  NaN
# Drama,Sci-Fi                 18.620000
# ...

# %%
rev_t.to_csv('dataset\genre.csv')

# %%
rev_t_df=pd.read_csv('dataset\genre.csv')

# %%
rev_t_df.columns
# Out:
# Index(['Genre', 'Revenue'], dtype='object')

# %%
rev_gen_df_n.head(n=50)
# Out:
#                           Genre  Revenue
# 7                        Comedy      NaN
# 22           Crime,Drama,Horror      NaN
# 25                       Comedy      NaN
# 39                 Comedy,Drama      NaN
# 42                       Horror      NaN
# 47      Adventure,Drama,Fantasy      NaN
# 49                        Drama      NaN
# 61      Horror,Mystery,Thriller      NaN
# 70                Drama,History      NaN
# 103      Crime,Mystery,Thriller      NaN
# 108                       Drama      NaN
# 112              Romance,Sci-Fi      NaN
# 123                      Action      NaN
# 139    Mystery,Thriller,Western      NaN
# 154        Drama,Horror,Mystery      NaN
# 160                Thriller,War      NaN
# 172            Adventure,Horror      NaN
# 183                      Sci-Fi      NaN
# 185               Drama,Romance      NaN
# 191                       Drama      NaN
# 196        Crime,Drama,Thriller      NaN
# 209       Drama,Horror,Thriller      NaN
# ...

# %%
rev_gen_df_n.info
# Out:
# <bound method DataFrame.info of                    Genre  Revenue
# 7                 Comedy      NaN
# 22    Crime,Drama,Horror      NaN
# 25                Comedy      NaN
# 39          Comedy,Drama      NaN
# 42                Horror      NaN
# ..                   ...      ...
# 977               Comedy      NaN
# 978                Drama      NaN
# 988               Horror      NaN
# 995  Crime,Drama,Mystery      NaN
# 998     Adventure,Comedy      NaN
#
# [128 rows x 2 columns]>

# %%
rev_t_df.columns
# Out:
# Index(['Genre', 'Revenue'], dtype='object')

# %%
rev_gen_df_n.columns
# Out:
# Index(['Genre', 'Revenue'], dtype='object')

# %%
rev_gen_df_n.to_csv('dataset/genre_null.csv')

# %%
rev_gen_df_n['Revenue']=rev_gen_df_n['Genre'].map(rev_t_df.set_index('Genre')['Revenue'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-639-32affb5c5e20> in <module>
# ----> 1 rev_gen_df_n['Revenue']=rev_gen_df_n['Genre'].map(rev_t_df.set_index('Genre')['Revenue'],inplace=True)
#
# TypeError: map() got an unexpected keyword argument 'inplace'

# %%
rev_gen_df_n.to_csv('dataset/rev_gen_df_n.csv')

# %%
rev_gen_df.isnull().sum()
# Out:
# Genre        0
# Revenue    128
# dtype: int64

# %%
mov_df_1=pd.read_csv("dataset/IMDB-Movie-Data.csv")

# %%
mov_df_1.rename(columns={
    'Revenue (Millions)':'Revenue',
    'Runtime (Minutes)' :'Runtime'
},inplace=True)

# %%
mov_df_1['Revenue_1']=mov_df_1['Genre'].map(rev_t_df.set_index('Genre')['Revenue'])

# %%
mov_df_1.isnull().sum()
# Out:
# Rank             0
# Title            0
# Genre            0
# Description      0
# Director         0
# Actors           0
# Year             0
# Runtime          0
# Rating           0
# Votes            0
# Revenue        128
# Metascore       64
# Revenue_1       12
# dtype: int64

# %%
mov_df_1.to_csv('dataset/mov_df_1.csv')

# %%
import numpy as np
mov_df_1['Revenue'] = np.where(mov_df_1['Revenue'].isnull(), mov_df_1['Revenue_1'], mov_df_1['Revenue'])

# %%
mov_df_1.to_csv('dataset/mov_df_1.csv')

# %%
mov_df_1.isnull().sum()
# Out:
# Rank            0
# Title           0
# Genre           0
# Description     0
# Director        0
# Actors          0
# Year            0
# Runtime         0
# Rating          0
# Votes           0
# Revenue        12
# Metascore      64
# Revenue_1      12
# dtype: int64

# %%
df1.head()
# Out:
#      name course_name Course_id Course_teacher
# 0  Azizul  Statistics         1         Sentos
# 1  Shiplu     Physics         2           John
# 2   Turan          AI         3             CK
# 3    arif     Physics         2           John
# 4  Dhiman          AI                       CK

# %%
course_id = [1,2,3,2,3]

# %%
df1['course_id_1']=course_id

# %%
df1.head()
# Out:
#      name course_name Course_id Course_teacher  course_id_1
# 0  Azizul  Statistics         1         Sentos            1
# 1  Shiplu     Physics         2           John            2
# 2   Turan          AI         3             CK            3
# 3    arif     Physics         2           John            2
# 4  Dhiman          AI                       CK            3

# %%
df1=df1.append({'name':['Chaity'],
                         'course_name':['Physics'],
                         'Course_id':[''],
                         'Course_teacher':['John'],
                        'course_id_1':['2']},ignore_index=True)

# %%
df2.head(n=60)
# Out:
#       name course_name Course_id Course_teacher  course_id_1
# 0   Azizul  Statistics         1         Sentos          1.0
# 1   Shiplu     Physics         2           John          2.0
# 2    Turan          AI         3             CK          3.0
# 3     arif     Physics         2           John          2.0
# 4   Dhiman          AI                       CK          3.0
# 5    Chait     Physics                     John          NaN
# 6    Chait     Physics                     John          NaN
# 7   Azizul  Statistics         1         Sentos          1.0
# 8   Shiplu     Physics         2           John          2.0
# 9    Turan          AI         3             CK          3.0
# 10    arif     Physics         2           John          2.0
# 11  Dhiman          AI                       CK          3.0
# 12   Chait     Physics                     John          NaN
# 13   Chait     Physics                     John          NaN
# ...

# %%
course_outline.head()
# Out:
#   course_name Course_id Course_teacher
# 0  Statistics       001         Sentos
# 1     Physics       002           John
# 2          AI       003             CK

# %%
df2['course_id_1']=df2['course_name'].map(course_outline.set_index('course_name')['Course_id'])

# %%
df2.head(n=60)
# Out:
#       name course_name Course_id Course_teacher course_id_1
# 0   Azizul  Statistics         1         Sentos         001
# 1   Shiplu     Physics         2           John         002
# 2    Turan          AI         3             CK         003
# 3     arif     Physics         2           John         002
# 4   Dhiman          AI                       CK         003
# 5    Chait     Physics                     John         002
# 6    Chait     Physics                     John         002
# 7   Azizul  Statistics         1         Sentos         001
# 8   Shiplu     Physics         2           John         002
# 9    Turan          AI         3             CK         003
# 10    arif     Physics         2           John         002
# 11  Dhiman          AI                       CK         003
# 12   Chait     Physics                     John         002
# 13   Chait     Physics                     John         002
# 14  Chaity     Physics                     John         002
# ...

# %%
df2['Course_id'] = np.where(df2['Course_id'].isnull(), df2['course_id_1'], df2['Course_id'])

# %%
df2.head(n=60)
# Out:
#       name course_name                                          Course_id  \
# 0   Azizul  Statistics  <pandas.core.strings.accessor.StringMethods ob...
# 1   Shiplu     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 2    Turan          AI  <pandas.core.strings.accessor.StringMethods ob...
# 3     arif     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 4   Dhiman          AI  <pandas.core.strings.accessor.StringMethods ob...
# 5    Chait     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 6    Chait     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 7   Azizul  Statistics  <pandas.core.strings.accessor.StringMethods ob...
# 8   Shiplu     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 9    Turan          AI  <pandas.core.strings.accessor.StringMethods ob...
# 10    arif     Physics  <pandas.core.strings.accessor.StringMethods ob...
# 11  Dhiman          AI  <pandas.core.strings.accessor.StringMethods ob...
# ...

# %%
df2.to_csv('dataset/df2.csv')

# %%
df2=pd.read_csv('dataset/df2.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-749-41553795bbd3> in <module>
# ----> 1 df2=pd.read_csv('dataset/df2.csv',index=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df2.head(n=60)
# Out:
#     Unnamed: 0    name course_name  Course_id Course_teacher  course_id_1
# 0            0  Azizul  Statistics        1.0         Sentos            1
# 1            1  Shiplu     Physics        2.0           John            2
# 2            2   Turan          AI        3.0             CK            3
# 3            3    arif     Physics        NaN           John            2
# 4            4  Dhiman          AI        NaN             CK            3
# 5            5   Chait     Physics        NaN           John            2
# 6            6   Chait     Physics        2.0           John            2
# 7            7  Azizul  Statistics        1.0         Sentos            1
# 8            8  Shiplu     Physics        2.0           John            2
# 9            9   Turan          AI        3.0             CK            3
# 10          10    arif     Physics        NaN           John            2
# 11          11  Dhiman          AI        NaN             CK            3
# ...

# %%
df2['Course_id'] = np.where(df2['Course_id'].isnull(), df2['course_id_1'], df2['Course_id'])

# %%
df2.head(n=35)
# Out:
#     Unnamed: 0    name course_name  Course_id Course_teacher  course_id_1
# 0            0  Azizul  Statistics        1.0         Sentos            1
# 1            1  Shiplu     Physics        2.0           John            2
# 2            2   Turan          AI        3.0             CK            3
# 3            3    arif     Physics        2.0           John            2
# 4            4  Dhiman          AI        3.0             CK            3
# 5            5   Chait     Physics        2.0           John            2
# 6            6   Chait     Physics        2.0           John            2
# 7            7  Azizul  Statistics        1.0         Sentos            1
# 8            8  Shiplu     Physics        2.0           John            2
# 9            9   Turan          AI        3.0             CK            3
# 10          10    arif     Physics        2.0           John            2
# 11          11  Dhiman          AI        3.0             CK            3
# ...

# %%
df2.dtypes
# Out:
# Unnamed: 0          int64
# name               object
# course_name        object
# Course_id         float64
# Course_teacher     object
# course_id_1         int64
# dtype: object

# %%
# Remove Unnamed column

df2.columns.str.match("Unnamed")
df2.loc[:,~df2.columns.str.match("Unnamed")]
# Out:
#       name course_name  Course_id Course_teacher  course_id_1
# 0   Azizul  Statistics        1.0         Sentos            1
# 1   Shiplu     Physics        2.0           John            2
# 2    Turan          AI        3.0             CK            3
# 3     arif     Physics        2.0           John            2
# 4   Dhiman          AI        3.0             CK            3
# 5    Chait     Physics        2.0           John            2
# 6    Chait     Physics        2.0           John            2
# 7   Azizul  Statistics        1.0         Sentos            1
# 8   Shiplu     Physics        2.0           John            2
# 9    Turan          AI        3.0             CK            3
# 10    arif     Physics        2.0           John            2
# 11  Dhiman          AI        3.0             CK            3
# 12   Chait     Physics        2.0           John            2
# 13   Chait     Physics        2.0           John            2
# ...

# %%
df2.to_csv('dataset/df2.csv',index=False)

# %%
df2=pd.read_csv('dataset/df2.csv')

# %%
df2.head(n=40)
# Out:
#     Unnamed: 0  Unnamed: 0.1    name course_name  Course_id Course_teacher  \
# 0            0             0  Azizul  Statistics        1.0         Sentos
# 1            1             1  Shiplu     Physics        2.0           John
# 2            2             2   Turan          AI        3.0             CK
# 3            3             3    arif     Physics        2.0           John
# 4            4             4  Dhiman          AI        3.0             CK
# 5            5             5   Chait     Physics        2.0           John
# 6            6             6   Chait     Physics        2.0           John
# 7            7             7  Azizul  Statistics        1.0         Sentos
# 8            8             8  Shiplu     Physics        2.0           John
# 9            9             9   Turan          AI        3.0             CK
# 10          10            10    arif     Physics        2.0           John
# ...

# %%
df2.drop("Unnamed: 0.1",axis=1)
# Out:
#     Unnamed: 0    name course_name  Course_id Course_teacher  course_id_1
# 0            0  Azizul  Statistics        1.0         Sentos            1
# 1            1  Shiplu     Physics        2.0           John            2
# 2            2   Turan          AI        3.0             CK            3
# 3            3    arif     Physics        2.0           John            2
# 4            4  Dhiman          AI        3.0             CK            3
# 5            5   Chait     Physics        2.0           John            2
# 6            6   Chait     Physics        2.0           John            2
# 7            7  Azizul  Statistics        1.0         Sentos            1
# 8            8  Shiplu     Physics        2.0           John            2
# 9            9   Turan          AI        3.0             CK            3
# 10          10    arif     Physics        2.0           John            2
# 11          11  Dhiman          AI        3.0             CK            3
# ...

# %%
std = pd.read_csv('dataset/students.csv')

# %%
std.head()
# Out:
#      name course_name  Course_id Course_teacher
# 0  Azizul  Statistics        1.0         Sentos
# 1  Shiplu     Physics        2.0           John
# 2   Turan          AI        3.0             CK
# 3    Arif     Physics        NaN           John
# 4  Dhiman          AI        NaN             CK

# %%
cs = pd.read_csv('dataset/course_outline.csv')

# %%
cs.dtypes
# Out:
# course_name       object
# Course_id          int64
# Course_teacher    object
# dtype: object

# %%
std.head()
# Out:
#      name course_name  Course_id Course_teacher
# 0  Azizul  Statistics        1.0         Sentos
# 1  Shiplu     Physics        2.0           John
# 2   Turan          AI        3.0             CK
# 3    Arif     Physics        NaN           John
# 4  Dhiman          AI        NaN             CK

# %%
std['course_id_1']=std['course_name'].map(cs.set_index('course_name')['Course_id'])

# %%
std.head()
# Out:
#      name course_name  Course_id Course_teacher  course_id_1
# 0  Azizul  Statistics        1.0         Sentos            1
# 1  Shiplu     Physics        2.0           John            2
# 2   Turan          AI        3.0             CK            3
# 3    Arif     Physics        NaN           John            2
# 4  Dhiman          AI        NaN             CK            3

# %%
std['Course_id'] = np.where(std['Course_id'].isnull(), std['course_id_1'], std['Course_id'])

# %%
std.head()
# Out:
#      name course_name  Course_id Course_teacher  course_id_1
# 0  Azizul  Statistics        1.0         Sentos            1
# 1  Shiplu     Physics        2.0           John            2
# 2   Turan          AI        3.0             CK            3
# 3    Arif     Physics        2.0           John            2
# 4  Dhiman          AI        3.0             CK            3

# %%
std.drop(['course_id_1'], axis = 1,inplace=True)

# %%
std.head()
# Out:
#      name course_name  Course_id Course_teacher
# 0  Azizul  Statistics        1.0         Sentos
# 1  Shiplu     Physics        2.0           John
# 2   Turan          AI        3.0             CK
# 3    Arif     Physics        2.0           John
# 4  Dhiman          AI        3.0             CK
